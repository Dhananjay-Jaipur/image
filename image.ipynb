# %% [markdown]
# # IMAGE PROCESSING

# %% [markdown]
# ## liberary
# opencv
# scikit
# matplot

# %%
# !python -m pip install  opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !python -m pip install scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !python -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %% [markdown]
# image reading by opencv

# %%
img = cv2.imread("594c7130edddae5f071ff8468d88faeb.jpg")

# %%
img
# Out:
# array([[[249, 249, 249],
#         [249, 249, 249],
#         [249, 249, 249],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        [[249, 249, 249],
#         [249, 249, 249],
#         [249, 249, 249],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        [[249, 249, 249],
#         [249, 249, 249],
#         [249, 249, 249],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        ...,
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        [[242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242],
# ...

# %%
img.shape
# Out:
# (587, 735, 3)

# %% [markdown]
# 3 here represent chanel(R,G,B)

# %%
plt.imshow(img)

# %%
img = cv2.imread("red.jpg")

# %%
img
# Out:
# array([[[ 2,  0,  0],
#         [ 3,  1,  1],
#         [ 4,  2,  2],
#         ...,
#         [ 2,  0,  0],
#         [ 2,  0,  0],
#         [ 2,  0,  0]],
#
#        [[ 3,  0,  2],
#         [ 2,  1,  3],
#         [ 5,  2,  4],
#         ...,
#         [ 1,  1,  1],
#         [ 1,  0,  2],
#         [ 1,  1,  1]],
#
#        [[ 0,  0,  6],
#         [ 0,  0,  8],
#         [ 3,  0,  9],
#         ...,
#         [ 0,  0,  5],
#         [ 0,  0,  7],
#         [ 0,  0,  5]],
#
#        ...,
#
#        [[ 5,  5, 35],
#         [ 6,  6, 36],
#         [ 7,  7, 37],
#         ...,
#         [ 5,  6, 40],
#         [ 5,  6, 40],
#         [ 5,  6, 40]],
#
#        [[ 0,  1, 22],
#         [ 1,  2, 23],
#         [ 2,  2, 26],
#         ...,
#         [ 1,  2, 28],
#         [ 1,  2, 28],
#         [ 1,  2, 28]],
#
#        [[ 0,  0, 17],
#         [ 0,  0, 17],
#         [ 0,  0, 18],
#         ...,
#         [ 0,  0, 20],
#         [ 0,  0, 20],
#         [ 0,  0, 20]]], dtype=uint8)

# %%
plt.imshow(img)

# %% [markdown]
# openCV = B G R

# %% [markdown]
# matplot = R G B

# %% [markdown]
# slicing image

# %%
list = [1,2,3,4,5,6,7,8,9]
list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
list[0:9:2] # starting point    end point     step(skip)
# Out:
# [1, 3, 5, 7, 9]

# %%
list[9:0:-1]
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2]

# %%
list[::-1] #we can also write life this
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
img = img[:,:,::-1] # here we are changing plane
img
# Out:
# array([[[ 0,  0,  2],
#         [ 1,  1,  3],
#         [ 2,  2,  4],
#         ...,
#         [ 0,  0,  2],
#         [ 0,  0,  2],
#         [ 0,  0,  2]],
#
#        [[ 2,  0,  3],
#         [ 3,  1,  2],
#         [ 4,  2,  5],
#         ...,
#         [ 1,  1,  1],
#         [ 2,  0,  1],
#         [ 1,  1,  1]],
#
#        [[ 6,  0,  0],
#         [ 8,  0,  0],
#         [ 9,  0,  3],
#         ...,
#         [ 5,  0,  0],
#         [ 7,  0,  0],
#         [ 5,  0,  0]],
#
#        ...,
#
#        [[35,  5,  5],
#         [36,  6,  6],
#         [37,  7,  7],
#         ...,
#         [40,  6,  5],
#         [40,  6,  5],
#         [40,  6,  5]],
#
#        [[22,  1,  0],
#         [23,  2,  1],
#         [26,  2,  2],
#         ...,
#         [28,  2,  1],
#         [28,  2,  1],
#         [28,  2,  1]],
#
#        [[17,  0,  0],
#         [17,  0,  0],
#         [18,  0,  0],
#         ...,
#         [20,  0,  0],
#         [20,  0,  0],
#         [20,  0,  0]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,::-1,:])

# %%
plt.imshow(img[::-1,:,:])

# %%
plt.imshow(img[::-1,:,::-1])

# %%
plt.imshow(img[:-1,:,:])

# %%
img = img[:,:,::-1]
plt.imshow(img)

# %%
plt.imshow(img[:,:,::4])

# %%
plt.imshow(img[200:,200:520,:])

# %%
ord("q") # tells the ascii value
# Out:
# 113

# %%
def image_show(i):
    img = cv2.imread(i)
    cv2.imshow("demo",img)
    key = cv2.waitKey(0)
    if key == ord("c"):   
        cv2.destroyAllWindows()

# %%
image_show("red.jpg")
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/mrvip/.var/app/com.visualstudio.code-oss/data/python/lib/python3.10/site-packages/cv2/qt/plugins"
# Qt: Session management error: None of the authentication protocols specified are supported

# %%
s = "puneet.suthar"
s.split(".")
# Out:
# ['puneet', 'suthar']

# %%
"puneet.suthar".split(".")[0]
# Out:
# 'puneet'

# %%
def image_name(i):
    img = cv2.imread(i)
    cv2.imshow(i.split("."),img)
    key = cv2.waitKey(0)
    if key == ord("c"):   
        cv2.destroyAllWindows()
